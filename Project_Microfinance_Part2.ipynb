# %%
import pandas as pd

# %%
df= pd.read_csv("final_sheet.csv")

# %%
df
# Out:
#                 Names    Village  Monthly Income  Family Members  \
# 0        Mark Koewler  Village 2           11378               8
# 1       Sandra Parker  Village 3           11369               8
# 2       Shannon Sears  Village 4            3882               3
# 3       Vincent Voeks  Village 4           12316               7
# 4     Marcelino Bekis  Village 1            9859               6
# ..                ...        ...             ...             ...
# 395    Shayne Dickson  Village 1            9946               6
# 396     Joseph Waters  Village 3            6015               6
# 397     Sharon Ybarra  Village 4            9480               5
# 398  Jerry Schreffler  Village 3            4926               3
# 399    Angeline Seidt  Village 2            8069               4
#
#     Connected to grid     Why not connected to grid?  \
# 0                  No                No grid near by
# 1                  No  Can't afford electricity bill
# ...

# %%
df.describe()
# Out:
#        Monthly Income  Family Members  Electricity available per day(in hrs)  \
# count      400.000000      400.000000                             400.000000
# mean      8069.295000        5.097500                               6.357500
# std       3472.169081        2.010747                               7.129992
# min       3012.000000        2.000000                               0.000000
# 25%       4750.250000        3.000000                               3.000000
# 50%       7910.500000        5.000000                               4.000000
# 75%      10579.750000        7.000000                               5.000000
# max      14984.000000        8.000000                              22.000000
#
#        Electrical appliances  Mobile Charger(Wh)  5W LED Torch  10W LED Torch  \
# count             400.000000           400.00000    400.000000     400.000000
# mean                4.965000            14.00000      1.975000      12.575000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 55 columns):
# Names                                                    400 non-null object
# Village                                                  400 non-null object
# Monthly Income                                           400 non-null int64
# Family Members                                           400 non-null int64
# Connected to grid                                        400 non-null object
# Why not connected to grid?                               400 non-null object
# Electricity available per day(in hrs)                    400 non-null int64
# Electrical appliances                                    400 non-null int64
# Mobile Charger(Wh)                                       400 non-null int64
# 5W LED Torch                                             400 non-null int64
# 10W LED Torch                                            400 non-null int64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.countplot(x= "Connected to grid", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Connected to grid"].value_counts()
# Out:
# Yes    213
# No     187
# Name: Connected to grid, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Why not connected to grid?", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Why not connected to grid?"].value_counts()
# Out:
# Already Connected                213
# Can't afford electricity bill     69
# Connection cost is very high      60
# No grid near by                   58
# Name: Why not connected to grid?, dtype: int64

# %%
plt.figure(figsize=(14, 6))
sns.countplot(x= "Who do you pay", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Who do you pay"].value_counts()
# Out:
# No one (for free)                 129
# Pre-paid meter card seller         76
# Landlord                           69
# Community/village/municipality     68
# Not connected to grid              58
# Name: Who do you pay, dtype: int64

# %%
plt.figure(figsize=(14, 6))
sns.countplot(x= "Electrical appliances", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Electrical appliances"].value_counts()
# Out:
# 7    104
# 5     96
# 0     58
# 9     51
# 4     46
# 3     45
# Name: Electrical appliances, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Did you use KEROSENE/FUEL-BASED /CANDLE LIGHTING", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Did you use KEROSENE/FUEL-BASED /CANDLE LIGHTING"].value_counts()
# Out:
# No     293
# Yes    107
# Name: Did you use KEROSENE/FUEL-BASED /CANDLE LIGHTING, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Rechargeable batteries", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Rechargeable batteries"].value_counts()
# Out:
# Yes    334
# No      66
# Name: Rechargeable batteries, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Solar devices",data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Solar devices"].value_counts()
# Out:
# No     330
# Yes     70
# Name: Solar devices, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Why no Solar?", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Willing to shift to solar applicanes", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Willing to shift to solar applicanes"].value_counts()
# Out:
# Yes              173
# No               157
# Already using     70
# Name: Willing to shift to solar applicanes, dtype: int64

# %%
sns.boxplot(x= "Electrical appliances", y="Monthly Income", data= df)

# %%
sns.countplot(x= "Village", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize= (28,12))
sns.countplot("Capacity(Wh)", data= df)
plt.xlabel("Capacity(Wh)")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Capacity(Wh)"].value_counts()
# Out:
# 0       58
# 275     57
# 515     50
# 260     30
# 140     29
# 45      26
# 85      25
# 1210    24
# 660     21
# 25      16
# 1055    14
# 170     13
# 90      11
# 720     10
# 4090     8
# 1185     8
# Name: Capacity(Wh), dtype: int64

# %%
plt.figure(figsize= (10,6))
sns.countplot(x= "Capacity Tier", data= df)
plt.xlabel("Capacity Tier Ranking")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize= (10,6))
sns.countplot("Electricity available per day(in hrs)", data= df, hue= "Village")
plt.xlabel("Electricity available per day(in hrs)")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize= (10,6))
sns.countplot(x= "Availabilty Tier", data= df)
plt.xlabel("Availability Tier Ranking")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Availabilty Tier"].value_counts()
# Out:
# 2    172
# 0    162
# 4     66
# Name: Availabilty Tier, dtype: int64

# %%
plt.figure(figsize= (10,6))
sns.countplot(x= "Power cuts per week", data= df, hue= "Village")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize= (10,6))
sns.countplot(x= "Reliability Tier", data= df)
plt.xlabel("Reliability Tier Ranking")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Reliability Tier"].value_counts()
# Out:
# 3    172
# 4    170
# 5     58
# Name: Reliability Tier, dtype: int64

# %%
plt.figure(figsize= (15,6))
sns.countplot(x= "Voltage problems if any", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Voltage problems if any"].value_counts()
# Out:
# No Problem                                 92
# Fluctuations                               89
# Electrical applicances getting affected    81
# Long Power Cuts                            80
# Not connected to grid                      58
# Name: Voltage problems if any, dtype: int64

# %%
plt.figure(figsize= (8,6))
sns.countplot(x= "Quality Tier", data= df)
plt.xlabel("Quality Tier Ranking")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Quality Tier"].value_counts()
# Out:
# 3    308
# 5     92
# Name: Quality Tier, dtype: int64

# %%
plt.figure(figsize= (8,6))
df["Monthly Income"].plot(kind= "hist")
plt.xlabel("Monthly Income")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize= (8,6))
sns.countplot(x= "Affordability Tier", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Affordability Tier"].value_counts()
# Out:
# 5    251
# 2    149
# Name: Affordability Tier, dtype: int64

# %%
def affordability(af):
    if af*0.05*12 > 3766.8: afford= "Yes"
    else: afford= "No"
    return(afford)
df["Affordability"]= df["Monthly Income"].apply(affordability)
plt.figure(figsize= (8,6))
sns.countplot(x= "Affordability", data= df)
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize= (13,6))
sns.countplot(x= "Who do you pay", data= df)
plt.xlabel("Payment of electricity bill")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Legality Tier"].value_counts()
# Out:
# 5    271
# 3    129
# Name: Legality Tier, dtype: int64

# %%
plt.figure(figsize= (8,6))
sns.countplot(x= "Legality Tier", data= df)
plt.xlabel("Legality Tier Ranking")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize= (8,6))
sns.countplot(x= "Household members die because of the grid electricity", data= df)
plt.xlabel("Household members die because of the grid electricity")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Health & Safety Tier"].value_counts()
# Out:
# 3    225
# 5    175
# Name: Health & Safety Tier, dtype: int64

# %%
plt.figure(figsize= (8,6))
sns.countplot("Health & Safety Tier", data= df)
plt.xlabel("Health & Safety Tier Ranking")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Tier Ranking", data= df)
plt.xlabel("Tier Ranking")
plt.ylabel("Households")
# Out:
# Text(0, 0.5, 'Households')

# %%
df["Tier Ranking"].value_counts()
# Out:
# 0    162
# 2    142
# 1     67
# 3     28
# 4      1
# Name: Tier Ranking, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Minimum temperature in Winter", data= df)
plt.xlabel("Temperatue (C)")
# Out:
# Text(0.5, 0, 'Temperatue (C)')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "Maximum temperature in Summer", data= df)
plt.xlabel("Temperatue (C)")
# Out:
# Text(0.5, 0, 'Temperatue (C)')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x= "How many months does it rain", data= df)

# %%
plt.figure(figsize=(16, 14))
cor= df.corr()
sns.heatmap(cor, annot= True, linewidths= 1, cmap=plt.cm.Reds)

# %%
#Correlation with output variable
cor_target = abs(cor["Tier Ranking"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.70]
relevant_features
# Out:
# Mobile Charger(Wh)    0.704652
# 5W LED Bulb(Wh)       0.763439
# 10W LED Bulb(Wh)      0.769245
# 45W Fan(Wh)           0.765162
# Capacity Tier         0.742838
# Availabilty Tier      0.828270
# Tier Ranking          1.000000
# Name: Tier Ranking, dtype: float64

# %% [markdown]
# ## Selection of 4 most highly correlated features from the above 6 features
# ## Finding correlation between all the 6 features and eliminating one which is highly correlated with each other and also one of them which is less correlated with the target variable

# %%
print(df[["5W LED Bulb(Wh)", "Availabilty Tier"]].corr())
print(df[["5W LED Bulb(Wh)", "10W LED Bulb(Wh)"]].corr())
print(df[["5W LED Bulb(Wh)", "45W Fan(Wh)"]].corr())
print(df[["5W LED Bulb(Wh)", "Capacity Tier"]].corr())
print(df[["5W LED Bulb(Wh)", "Mobile Charger(Wh)"]].corr())
print(df[["45W Fan(Wh)", "Availabilty Tier"]].corr())
print(df[["45W Fan(Wh)", "Capacity Tier"]].corr())
print(df[["45W Fan(Wh)", "10W LED Bulb(Wh)"]].corr())
print(df[["45W Fan(Wh)", "Mobile Charger(Wh)"]].corr())
print(df[["Capacity Tier", "Availabilty Tier"]].corr())
print(df[["Capacity Tier", "Mobile Charger(Wh)"]].corr())
print(df[["10W LED Bulb(Wh)", "Availabilty Tier"]].corr())
print(df[["10W LED Bulb(Wh)", "Capacity Tier"]].corr())
print(df[["10W LED Bulb(Wh)", "Mobile Charger(Wh)"]].corr())
print(df[["Mobile Charger(Wh)", "Availabilty Tier"]].corr())
# Out:
#                   5W LED Bulb(Wh)  Availabilty Tier
# 5W LED Bulb(Wh)          1.000000          0.823554
# Availabilty Tier         0.823554          1.000000
#                   5W LED Bulb(Wh)  10W LED Bulb(Wh)
# 5W LED Bulb(Wh)          1.000000          0.800125
# 10W LED Bulb(Wh)         0.800125          1.000000
#                  5W LED Bulb(Wh)  45W Fan(Wh)
# 5W LED Bulb(Wh)         1.000000     0.819335
# 45W Fan(Wh)             0.819335     1.000000
#                  5W LED Bulb(Wh)  Capacity Tier
# 5W LED Bulb(Wh)         1.000000       0.744995
# Capacity Tier           0.744995       1.000000
#                     5W LED Bulb(Wh)  Mobile Charger(Wh)
# 5W LED Bulb(Wh)            1.000000            0.863085
# Mobile Charger(Wh)         0.863085            1.000000
#                   45W Fan(Wh)  Availabilty Tier
# 45W Fan(Wh)          1.000000          0.622623
# Availabilty Tier     0.622623          1.000000
#                45W Fan(Wh)  Capacity Tier
# ...

# %% [markdown]
# ## Below are the 4 most highly correlated features
# ## 10W LED Bulb(Wh)      0.769245
# ## 45W Fan(Wh)           0.765162
# ## Capacity Tier         0.742838
# ## Availabilty Tier      0.828270

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
scaler = MinMaxScaler()

scaler.fit(df[["Availabilty Tier"]])
df["Availabilty Tier"] = scaler.transform(df[["Availabilty Tier"]])

scaler.fit(df[["Electricity available per day(in hrs)"]])
df["Electricity available per day(in hrs)"] = scaler.transform(df[["Electricity available per day(in hrs)"]])

# %%
#Using the elbow method to find the optimal number of clusters
X1= df[["Electricity available per day(in hrs)", "Availabilty Tier"]]

wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

plt.scatter(df["Electricity available per day(in hrs)"], df["Availabilty Tier"])
plt.xlabel("Electricity available per day(in hrs)")
plt.ylabel("Availabilty Tier")
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:972: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (6). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:972: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (7). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:972: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:972: ConvergenceWarning: Number of distinct clusters (5) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return_n_iter=True)
# ...

# %%
#Fitting K-MEans to the dataset
kmeans=KMeans(n_clusters= 2)
y_kmeans= kmeans.fit_predict(X1)

df["Cluster"]= y_kmeans

#Visualize the clusters
df1 = df[df.Cluster==0]
df2 = df[df.Cluster==1]
#df3 = df[df.Cluster==2]

plt.scatter(df1["Electricity available per day(in hrs)"],df1["Availabilty Tier"],color='green', label= "Cluster 1")
plt.scatter(df2["Electricity available per day(in hrs)"],df2["Availabilty Tier"],color='red', label= "Cluster 2")
#plt.scatter(df3["Electric bill of last month"],df3['Electrical appliances'],color='blue')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='purple', marker= "*", label='Centroids')

plt.title("Clusters of customers")
plt.xlabel("Electricity available per day(in hrs)")
plt.ylabel("Availabilty Tier")
plt.legend()

# %%
scaler = MinMaxScaler()

scaler.fit(df[["10W LED Bulb(Wh)"]])
df["10W LED Bulb(Wh)"] = scaler.transform(df[["10W LED Bulb(Wh)"]])

scaler.fit(df[["Monthly Income"]])
df["Monthly Income"] = scaler.transform(df[["Monthly Income"]])

# %%
#Using the elbow method to find the optimal number of clusters
X1= df[["Monthly Income", "10W LED Bulb(Wh)"]]

wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

plt.scatter(df["Monthly Income"], df["10W LED Bulb(Wh)"])
plt.xlabel("Monthly Income")
plt.ylabel("10W LED Bulb(Wh)")
# Out:
# Text(0, 0.5, '10W LED Bulb(Wh)')

# %%
#Fitting K-MEans to the dataset
kmeans=KMeans(n_clusters= 2)
y_kmeans= kmeans.fit_predict(X1)

df["Cluster"]= y_kmeans

#Visualize the clusters
df1 = df[df.Cluster==0]
df2 = df[df.Cluster==1]
df3 = df[df.Cluster==2]

plt.scatter(df1["Monthly Income"],df1["10W LED Bulb(Wh)"],color='green', label= "Cluster 1")
plt.scatter(df2["Monthly Income"],df2["10W LED Bulb(Wh)"],color='red', label= "Cluster 2")
plt.scatter(df3["Monthly Income"],df3["10W LED Bulb(Wh)"],color='blue', label= "Cluster 3")

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='purple', marker= "*", label='Centroids')

plt.title('Clusters of customers')
plt.xlabel('Monthly Income')
plt.ylabel('10W LED Bulb(Wh)')
plt.legend()

# %%
scaler = MinMaxScaler()

scaler.fit(df[['45W Fan(Wh)']])
df['45W Fan(Wh)'] = scaler.transform(df[['45W Fan(Wh)']])

scaler.fit(df[['Family Members']])
df['Family Members'] = scaler.transform(df[['Family Members']])

# %%
#Using the elbow method to find the optimal number of clusters
X1= df[["Family Members", "45W Fan(Wh)"]]

wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

plt.scatter(df["Family Members"], df["45W Fan(Wh)"])
plt.title('Clusters of customers')
plt.xlabel('Family Members')
plt.ylabel('45W Fan(Wh)')
# Out:
# Text(0, 0.5, '45W Fan(Wh)')

# %%
#Fitting K-MEans to the dataset
kmeans=KMeans(n_clusters= 3)
y_kmeans= kmeans.fit_predict(X1)

df["Cluster"]= y_kmeans

#Visualize the clusters
df1 = df[df.Cluster==0]
df2 = df[df.Cluster==1]
df3 = df[df.Cluster==2]

plt.scatter(df1['Family Members'], df1["45W Fan(Wh)"],color='green', label= "Cluster 1")
plt.scatter(df2['Family Members'], df2["45W Fan(Wh)"],color='red', label= "Cluster 2")
plt.scatter(df3['Family Members'], df3["45W Fan(Wh)"],color='blue', label= "Cluster 3")

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='purple', marker= "*",label='Centroids')

plt.title('Clusters of customers')
plt.ylabel('45W Fan(Wh)')
plt.xlabel('Family Members')
plt.legend()

# %%
scaler = MinMaxScaler()

scaler.fit(df[['Capacity Tier']])
df['Capacity Tier'] = scaler.transform(df[['Capacity Tier']])

scaler.fit(df[['Electrical appliances']])
df['Electrical appliances'] = scaler.transform(df[['Electrical appliances']])

# %%
#Using the elbow method to find the optimal number of clusters
X1= df[["Electrical appliances", "Capacity Tier"]]

wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

plt.scatter(df["Electrical appliances"], df["Capacity Tier"])
plt.title('Clusters of customers')
plt.ylabel('Capacity Tier')
plt.xlabel('Electrical appliances')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#Fitting K-MEans to the dataset
kmeans=KMeans(n_clusters= 2)
y_kmeans= kmeans.fit_predict(X1)

df["Cluster"]= y_kmeans

#Visualize the clusters
df1 = df[df.Cluster==0]
df2 = df[df.Cluster==1]
#df3 = df[df.Cluster==2]

plt.scatter(df1["Electrical appliances"], df1["Capacity Tier"],color='green', label= "Cluster 1")
plt.scatter(df2['Electrical appliances'], df2["Capacity Tier"],color='red',  label= "Cluster 2")
#plt.scatter(df3['Units Monthly'], df3["Capacity Tier"],color='blue',  label= "Cluster 3")

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='purple', marker= "*", label='Centroids')

plt.title('Clusters of customers')
plt.ylabel('Capacity Tier')
plt.xlabel('Electrical appliances')
plt.legend()
